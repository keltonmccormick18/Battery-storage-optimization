# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from pathlib import Path
from scipy.stats import norm
from scipy.optimize import minimize
from statsmodels.graphics.tsaplots import plot_acf
import math

import sys
sys.path.append('..')
from src.price_model import *
from src.optimization import *
from src.simulation import *

DATA_DIR = Path("../data")
ciso = pd.read_csv(DATA_DIR / "prices_CISO.csv")
nyiso = pd.read_csv(DATA_DIR / "prices_NYIS.csv")

# Parse datetime and extract components
ciso["hour"] = pd.to_datetime(ciso["hour"])
ciso["hour_of_day"] = ciso["hour"].dt.hour
ciso["dow"] = ciso["hour"].dt.dayofweek
ciso["month"] = ciso["hour"].dt.month

nyiso["hour"] = pd.to_datetime(nyiso["hour"])
nyiso["hour_of_day"] = nyiso["hour"].dt.hour
nyiso["dow"] = nyiso["hour"].dt.dayofweek
nyiso["month"] = nyiso["hour"].dt.month

# %%
ciso_results = walk_forward_backtest(ciso)
ciso_revenues = [r["revenue"] for r in ciso_results]
# Out:
# Week  1 | rev = $    16,235 | theta = 0.0213 | sigma=7.88 | mu=-14.57
# Week  2 | rev = $    10,319 | theta = 0.0178 | sigma=7.72 | mu=-14.56
# Week  3 | rev = $    15,746 | theta = 0.0206 | sigma=7.52 | mu=-13.28
# Week  4 | rev = $    21,949 | theta = 0.0198 | sigma=7.29 | mu=-8.33
# Week  5 | rev = $    19,593 | theta = 0.0190 | sigma=7.17 | mu=-8.27
# Week  6 | rev = $    18,423 | theta = 0.0160 | sigma=7.00 | mu=-7.69
# Week  7 | rev = $    10,708 | theta = 0.0123 | sigma=6.91 | mu=-4.13
# Week  8 | rev = $    18,364 | theta = 0.0137 | sigma=6.81 | mu=-6.29
# Week  9 | rev = $    25,163 | theta = 0.0203 | sigma=6.29 | mu=-6.65
# Week 10 | rev = $    24,377 | theta = 0.0177 | sigma=5.66 | mu=-7.91
# Week 11 | rev = $    19,088 | theta = 0.0100 | sigma=6.45 | mu=-7.28
# Week 12 | rev = $    23,249 | theta = 0.0153 | sigma=5.80 | mu=1.64
# Week 13 | rev = $    20,677 | theta = 0.0167 | sigma=5.81 | mu=2.26
# Week 14 | rev = $    26,022 | theta = 0.0157 | sigma=5.88 | mu=-1.48
# Week 15 | rev = $    18,089 | theta = 0.0152 | sigma=5.95 | mu=-5.46
# Week 16 | rev = $    18,138 | theta = 0.0105 | sigma=6.02 | mu=-0.69
# Week 17 | rev = $    18,365 | theta = 0.0110 | sigma=5.99 | mu=0.78
# Week 18 | rev = $    15,344 | theta = 0.0114 | sigma=5.90 | mu=-0.43
# Week 19 | rev = $    14,338 | theta = 0.0103 | sigma=5.94 | mu=4.12
# Week 20 | rev = $    29,170 | theta = 0.0149 | sigma=6.11 | mu=4.46
# Week 21 | rev = $    63,008 | theta = 0.0185 | sigma=6.57 | mu=-8.20
# Week 22 | rev = $    17,611 | theta = 0.0832 | sigma=14.72 | mu=-3.01
# Week 23 | rev = $    33,099 | theta = 0.0722 | sigma=14.89 | mu=-8.79
# Week 24 | rev = $    42,147 | theta = 0.0706 | sigma=16.39 | mu=-4.06
# Week 25 | rev = $    17,634 | theta = 0.1286 | sigma=17.89 | mu=-2.51
# Week 26 | rev = $     9,952 | theta = 0.1377 | sigma=18.72 | mu=-8.94
# Week 27 | rev = $     9,373 | theta = 0.2472 | sigma=19.29 | mu=-6.71
# Week 28 | rev = $    13,492 | theta = 0.2377 | sigma=19.25 | mu=-7.62
# Week 29 | rev = $    32,145 | theta = 0.3234 | sigma=19.57 | mu=-4.44
# Week 30 | rev = $        21 | theta = 0.3279 | sigma=22.39 | mu=5.04
# Week 31 | rev = $     9,119 | theta = 0.3279 | sigma=22.36 | mu=-5.81
# Week 32 | rev = $     6,910 | theta = 0.3272 | sigma=22.34 | mu=-2.33
# Week 33 | rev = $    36,959 | theta = 0.2245 | sigma=21.87 | mu=-0.73
# Week 34 | rev = $     4,086 | theta = 0.2948 | sigma=22.70 | mu=-0.23
# Week 35 | rev = $    -1,682 | theta = 0.2716 | sigma=17.73 | mu=-7.88
# Week 36 | rev = $     2,351 | theta = 0.2214 | sigma=17.39 | mu=-11.20
# Week 37 | rev = $     4,607 | theta = 0.1830 | sigma=15.65 | mu=-8.76
# Week 38 | rev = $     8,023 | theta = 0.1262 | sigma=13.99 | mu=-7.40
# Week 39 | rev = $     6,064 | theta = 0.1180 | sigma=12.62 | mu=-5.31
# Week 40 | rev = $       693 | theta = 0.1411 | sigma=12.70 | mu=-1.29
# Week 41 | rev = $     5,911 | theta = 0.1143 | sigma=12.66 | mu=5.99
# Week 42 | rev = $     4,370 | theta = 0.1411 | sigma=12.74 | mu=2.03
# Week 43 | rev = $     1,212 | theta = 0.0720 | sigma=7.38 | mu=-3.51
# Week 44 | rev = $     3,290 | theta = 0.0650 | sigma=7.47 | mu=-1.53
# Week 45 | rev = $     2,492 | theta = 0.0609 | sigma=7.52 | mu=-4.20
# Week 46 | rev = $     5,007 | theta = 0.0351 | sigma=7.51 | mu=-8.97
# Week 47 | rev = $    12,085 | theta = 0.0329 | sigma=5.39 | mu=-16.51
# Week 48 | rev = $    15,764 | theta = 0.0689 | sigma=5.07 | mu=-9.76
# Week 49 | rev = $    14,414 | theta = 0.0843 | sigma=5.14 | mu=3.44
# Week 50 | rev = $     9,377 | theta = 0.0756 | sigma=5.20 | mu=1.67
# Week 51 | rev = $    17,699 | theta = 0.0738 | sigma=5.23 | mu=1.51
# Week 52 | rev = $    19,870 | theta = 0.0892 | sigma=5.36 | mu=4.34
# Week 53 | rev = $    17,529 | theta = 0.1013 | sigma=5.55 | mu=2.06
# Week 54 | rev = $    25,126 | theta = 0.1069 | sigma=5.57 | mu=-0.17
# Week 55 | rev = $    26,162 | theta = 0.0547 | sigma=5.70 | mu=-1.96
# Week 56 | rev = $    18,643 | theta = 0.0636 | sigma=5.94 | mu=4.48
# Week 57 | rev = $    32,257 | theta = 0.0544 | sigma=5.92 | mu=5.24
# Week 58 | rev = $    24,561 | theta = 0.0585 | sigma=6.18 | mu=-2.55
# Week 59 | rev = $    27,929 | theta = 0.0364 | sigma=6.32 | mu=-10.56
# Week 60 | rev = $    27,385 | theta = 0.0441 | sigma=6.39 | mu=-2.18
# Week 61 | rev = $    25,321 | theta = 0.0414 | sigma=6.44 | mu=-0.23
# Week 62 | rev = $    21,895 | theta = 0.0417 | sigma=6.38 | mu=-2.30
# Week 63 | rev = $    21,518 | theta = 0.0454 | sigma=6.34 | mu=1.23
# Week 64 | rev = $    20,712 | theta = 0.0436 | sigma=6.24 | mu=3.45
# Week 65 | rev = $    18,889 | theta = 0.0394 | sigma=6.16 | mu=8.80
# Week 66 | rev = $    17,931 | theta = 0.0385 | sigma=5.97 | mu=1.20
# Week 67 | rev = $    14,372 | theta = 0.0336 | sigma=5.90 | mu=1.65
# Week 68 | rev = $    11,693 | theta = 0.0444 | sigma=5.83 | mu=5.77
# Week 69 | rev = $    14,049 | theta = 0.0447 | sigma=5.49 | mu=-0.39
# Week 70 | rev = $    13,775 | theta = 0.0516 | sigma=5.45 | mu=-3.12
# Week 71 | rev = $    11,459 | theta = 0.0671 | sigma=5.23 | mu=-3.36
# Week 72 | rev = $    11,558 | theta = 0.0344 | sigma=5.42 | mu=1.00
# Week 73 | rev = $     9,200 | theta = 0.0759 | sigma=5.10 | mu=-5.12
# Week 74 | rev = $     4,551 | theta = 0.0823 | sigma=4.99 | mu=-0.37
# Week 75 | rev = $     6,776 | theta = 0.0775 | sigma=4.99 | mu=-1.41
# Week 76 | rev = $     5,876 | theta = 0.0715 | sigma=4.99 | mu=-2.97
# Week 77 | rev = $     8,301 | theta = 0.0834 | sigma=5.08 | mu=-0.31
# Week 78 | rev = $     6,593 | theta = 0.0830 | sigma=5.02 | mu=3.62
# Week 79 | rev = $    10,600 | theta = 0.0963 | sigma=4.98 | mu=1.67
# Week 80 | rev = $     8,716 | theta = 0.0734 | sigma=5.04 | mu=7.18
# Week 81 | rev = $    10,800 | theta = 0.0653 | sigma=4.98 | mu=2.49
# Week 82 | rev = $     8,586 | theta = 0.0508 | sigma=4.87 | mu=5.19
# Week 83 | rev = $     7,567 | theta = 0.0614 | sigma=4.78 | mu=-0.54
# Week 84 | rev = $     4,834 | theta = 0.0804 | sigma=4.70 | mu=2.19
# Week 85 | rev = $     1,687 | theta = 0.1063 | sigma=4.62 | mu=-1.16
# Week 86 | rev = $     7,184 | theta = 0.1269 | sigma=4.55 | mu=-1.68
# Week 87 | rev = $    12,513 | theta = 0.1185 | sigma=4.38 | mu=0.05
# Week 88 | rev = $     8,016 | theta = 0.1150 | sigma=4.32 | mu=-1.25
# Week 89 | rev = $    10,538 | theta = 0.1239 | sigma=4.28 | mu=-1.00
# Week 90 | rev = $     5,759 | theta = 0.1040 | sigma=4.17 | mu=0.41
# Week 91 | rev = $    -2,822 | theta = 0.0969 | sigma=4.17 | mu=-0.25
# Week 92 | rev = $     3,368 | theta = 0.0791 | sigma=4.27 | mu=1.43
# Week 93 | rev = $     2,285 | theta = 0.1065 | sigma=4.19 | mu=2.63
# Week 94 | rev = $     2,809 | theta = 0.1198 | sigma=4.26 | mu=3.48
# Week 95 | rev = $      -338 | theta = 0.0889 | sigma=4.19 | mu=2.39
# Week 96 | rev = $    -1,883 | theta = 0.0916 | sigma=4.26 | mu=-2.87
# Week 97 | rev = $     4,553 | theta = 0.0667 | sigma=4.24 | mu=-5.48
# Week 98 | rev = $        50 | theta = 0.0623 | sigma=4.24 | mu=-8.98
# Week 99 | rev = $    10,324 | theta = 0.0620 | sigma=4.21 | mu=-5.45
# Week100 | rev = $    12,136 | theta = 0.0502 | sigma=4.24 | mu=-7.69
# Week101 | rev = $     6,469 | theta = 0.0430 | sigma=4.24 | mu=-7.02
# Week102 | rev = $     8,990 | theta = 0.0440 | sigma=4.34 | mu=6.83
# Week103 | rev = $     9,331 | theta = 0.0488 | sigma=4.42 | mu=-0.97
# Week104 | rev = $     4,028 | theta = 0.0535 | sigma=4.35 | mu=-5.27
# Week105 | rev = $     8,297 | theta = 0.0605 | sigma=4.21 | mu=-0.96
# Week106 | rev = $     8,699 | theta = 0.0637 | sigma=4.13 | mu=-1.29
# Week107 | rev = $    18,524 | theta = 0.0641 | sigma=4.08 | mu=-5.08
# Week108 | rev = $    22,155 | theta = 0.0705 | sigma=4.00 | mu=-6.00
# Week109 | rev = $    25,293 | theta = 0.0495 | sigma=4.08 | mu=-2.14
# Week110 | rev = $    14,414 | theta = 0.0398 | sigma=4.55 | mu=6.19
# Week111 | rev = $    16,078 | theta = 0.0438 | sigma=4.58 | mu=0.91
# Week112 | rev = $    11,296 | theta = 0.0627 | sigma=4.62 | mu=-1.54
# Week113 | rev = $    17,749 | theta = 0.0605 | sigma=4.56 | mu=-1.30
# Week114 | rev = $    10,565 | theta = 0.0523 | sigma=4.56 | mu=-2.94
# Mean weekly revenue: $13,717
# Std weekly revenue:  $10,060
# Sharpe (weekly):     1.36
# Worst week:          $-2,822
# % positive weeks:    96%
# Unique revenues: 113

# %%
nyiso_results = walk_forward_backtest(nyiso)
nyiso_revenues = [r["revenue"] for r in nyiso_results]
# Out:
# Week  1 | rev = $     4,345 | theta = 0.0144 | sigma=2.52 | mu=-7.59
# Week  2 | rev = $     4,056 | theta = 0.0102 | sigma=2.57 | mu=-12.82
# Week  3 | rev = $     5,368 | theta = 0.0100 | sigma=2.68 | mu=-10.76
# Week  4 | rev = $     3,761 | theta = 0.0126 | sigma=2.81 | mu=-1.47
# Week  5 | rev = $     4,577 | theta = 0.0117 | sigma=3.14 | mu=-3.08
# Week  6 | rev = $     3,845 | theta = 0.0293 | sigma=2.81 | mu=-3.82
# Week  7 | rev = $     4,475 | theta = 0.0306 | sigma=2.78 | mu=-3.58
# Week  8 | rev = $     3,125 | theta = 0.0356 | sigma=2.73 | mu=-1.89
# Week  9 | rev = $     2,970 | theta = 0.0312 | sigma=2.78 | mu=-1.93
# Week 10 | rev = $     3,077 | theta = 0.0301 | sigma=2.77 | mu=-4.29
# Week 11 | rev = $     2,627 | theta = 0.0284 | sigma=2.78 | mu=-5.78
# Week 12 | rev = $     1,723 | theta = 0.0251 | sigma=2.77 | mu=-4.69
# Week 13 | rev = $     2,042 | theta = 0.0504 | sigma=2.20 | mu=-3.48
# Week 14 | rev = $     1,654 | theta = 0.0123 | sigma=2.57 | mu=-2.61
# Week 15 | rev = $     1,545 | theta = 0.0287 | sigma=2.18 | mu=-5.27
# Week 16 | rev = $       520 | theta = 0.0280 | sigma=2.15 | mu=-3.39
# Week 17 | rev = $       842 | theta = 0.0415 | sigma=1.94 | mu=-2.05
# Week 18 | rev = $     2,040 | theta = 0.0294 | sigma=1.75 | mu=0.00
# Week 19 | rev = $     1,736 | theta = 0.0254 | sigma=1.71 | mu=-2.36
# Week 20 | rev = $     2,113 | theta = 0.0288 | sigma=1.69 | mu=-2.00
# Week 21 | rev = $     2,833 | theta = 0.0364 | sigma=1.58 | mu=-2.31
# Week 22 | rev = $     2,518 | theta = 0.0423 | sigma=1.46 | mu=-1.16
# Week 23 | rev = $     4,942 | theta = 0.0392 | sigma=1.40 | mu=-0.69
# Week 24 | rev = $     3,612 | theta = 0.0371 | sigma=1.46 | mu=-1.69
# Week 25 | rev = $     6,360 | theta = 0.0335 | sigma=1.44 | mu=-2.48
# Week 26 | rev = $     5,633 | theta = 0.0302 | sigma=1.44 | mu=-0.51
# Week 27 | rev = $     7,124 | theta = 0.0175 | sigma=1.51 | mu=0.58
# Week 28 | rev = $     7,994 | theta = 0.0238 | sigma=1.53 | mu=-4.14
# Week 29 | rev = $    10,722 | theta = 0.0265 | sigma=1.62 | mu=-1.69
# Week 30 | rev = $     9,626 | theta = 0.0496 | sigma=1.78 | mu=0.29
# Week 31 | rev = $     7,422 | theta = 0.0426 | sigma=1.90 | mu=1.22
# Week 32 | rev = $     7,204 | theta = 0.0604 | sigma=2.01 | mu=-0.30
# Week 33 | rev = $     6,948 | theta = 0.0565 | sigma=2.07 | mu=-1.18
# Week 34 | rev = $     7,524 | theta = 0.0494 | sigma=2.17 | mu=-0.62
# Week 35 | rev = $     6,048 | theta = 0.0417 | sigma=2.26 | mu=-0.78
# Week 36 | rev = $     5,070 | theta = 0.0525 | sigma=2.34 | mu=-0.89
# Week 37 | rev = $     3,503 | theta = 0.0533 | sigma=2.30 | mu=-0.03
# Week 38 | rev = $     2,839 | theta = 0.0562 | sigma=2.30 | mu=0.13
# Week 39 | rev = $     4,862 | theta = 0.0619 | sigma=2.25 | mu=-1.49
# Week 40 | rev = $     2,882 | theta = 0.0443 | sigma=2.20 | mu=0.72
# Week 41 | rev = $     4,083 | theta = 0.0608 | sigma=2.09 | mu=-1.61
# Week 42 | rev = $     4,121 | theta = 0.0590 | sigma=1.98 | mu=-1.55
# Week 43 | rev = $     4,542 | theta = 0.0663 | sigma=1.81 | mu=0.22
# Week 44 | rev = $     5,396 | theta = 0.0752 | sigma=1.72 | mu=0.51
# Week 45 | rev = $     3,119 | theta = 0.0652 | sigma=1.74 | mu=3.86
# Week 46 | rev = $     6,571 | theta = 0.0446 | sigma=1.72 | mu=-5.19
# Week 47 | rev = $     5,632 | theta = 0.0408 | sigma=1.73 | mu=-0.30
# Week 48 | rev = $     4,008 | theta = 0.0401 | sigma=1.76 | mu=1.39
# Week 49 | rev = $     5,319 | theta = 0.0394 | sigma=1.70 | mu=-2.07
# Week 50 | rev = $     5,114 | theta = 0.0407 | sigma=1.80 | mu=-0.82
# Week 51 | rev = $        18 | theta = 0.0412 | sigma=1.97 | mu=-0.99
# Week 52 | rev = $     5,389 | theta = 0.0348 | sigma=2.51 | mu=8.56
# Week 53 | rev = $     3,166 | theta = 0.0376 | sigma=2.66 | mu=0.87
# Week 54 | rev = $     4,337 | theta = 0.0423 | sigma=2.76 | mu=-1.96
# Week 55 | rev = $     5,560 | theta = 0.0495 | sigma=2.91 | mu=0.79
# Week 56 | rev = $     5,059 | theta = 0.0520 | sigma=3.01 | mu=1.14
# Week 57 | rev = $     1,516 | theta = 0.0508 | sigma=3.10 | mu=2.13
# Week 58 | rev = $     3,630 | theta = 0.0260 | sigma=3.57 | mu=14.07
# Week 59 | rev = $         0 | theta = 0.0269 | sigma=4.02 | mu=15.60
# Week 60 | rev = $       940 | theta = 0.0222 | sigma=4.61 | mu=19.69
# Week 61 | rev = $     2,234 | theta = 0.0201 | sigma=5.15 | mu=15.33
# Week 62 | rev = $     1,190 | theta = 0.0224 | sigma=5.19 | mu=-9.46
# Week 63 | rev = $     4,842 | theta = 0.0228 | sigma=5.26 | mu=6.36
# Week 64 | rev = $     3,043 | theta = 0.0235 | sigma=5.27 | mu=-2.42
# Week 65 | rev = $     4,356 | theta = 0.0196 | sigma=5.05 | mu=-4.54
# Week 66 | rev = $     4,127 | theta = 0.0203 | sigma=5.00 | mu=-7.30
# Week 67 | rev = $     3,203 | theta = 0.0165 | sigma=4.97 | mu=5.26
# Week 68 | rev = $     3,680 | theta = 0.0176 | sigma=4.90 | mu=4.27
# Week 69 | rev = $     3,276 | theta = 0.0185 | sigma=4.87 | mu=5.58
# Week 70 | rev = $     6,378 | theta = 0.0199 | sigma=4.84 | mu=4.44
# Week 71 | rev = $     3,387 | theta = 0.0146 | sigma=4.59 | mu=4.30
# Week 72 | rev = $     3,684 | theta = 0.0115 | sigma=4.24 | mu=2.82
# Week 73 | rev = $     7,047 | theta = 0.0100 | sigma=3.70 | mu=0.93
# Week 74 | rev = $     5,243 | theta = 0.0100 | sigma=2.99 | mu=2.27
# Week 75 | rev = $     9,867 | theta = 0.0100 | sigma=3.00 | mu=0.11
# Week 76 | rev = $     6,006 | theta = 0.0100 | sigma=2.84 | mu=5.17
# Week 77 | rev = $     8,126 | theta = 0.0100 | sigma=2.83 | mu=2.55
# Week 78 | rev = $    12,323 | theta = 0.0100 | sigma=2.85 | mu=1.99
# Week 79 | rev = $    11,660 | theta = 0.0100 | sigma=3.32 | mu=4.00
# Week 80 | rev = $    12,818 | theta = 0.0100 | sigma=2.96 | mu=7.95
# Week 81 | rev = $    13,797 | theta = 0.0100 | sigma=3.19 | mu=7.39
# Week 82 | rev = $    12,240 | theta = 0.0100 | sigma=3.47 | mu=7.11
# Week 83 | rev = $     6,710 | theta = 0.0100 | sigma=3.76 | mu=3.62
# Week 84 | rev = $    13,390 | theta = 0.0114 | sigma=3.60 | mu=1.61
# Week 85 | rev = $    14,061 | theta = 0.0140 | sigma=3.80 | mu=7.06
# Week 86 | rev = $    14,303 | theta = 0.0177 | sigma=4.10 | mu=7.06
# Week 87 | rev = $    17,414 | theta = 0.0226 | sigma=4.27 | mu=4.55
# Week 88 | rev = $     5,660 | theta = 0.0312 | sigma=4.49 | mu=4.20
# Week 89 | rev = $     8,509 | theta = 0.0556 | sigma=4.44 | mu=7.39
# Week 90 | rev = $    12,121 | theta = 0.0505 | sigma=4.50 | mu=10.64
# Week 91 | rev = $     8,656 | theta = 0.0394 | sigma=4.54 | mu=13.72
# Week 92 | rev = $     7,928 | theta = 0.0278 | sigma=4.48 | mu=5.16
# Week 93 | rev = $    11,169 | theta = 0.0316 | sigma=4.23 | mu=10.98
# Week 94 | rev = $    10,799 | theta = 0.0200 | sigma=4.05 | mu=14.68
# Week 95 | rev = $    11,802 | theta = 0.0143 | sigma=3.83 | mu=8.77
# Week 96 | rev = $    10,906 | theta = 0.0116 | sigma=3.64 | mu=3.99
# Week 97 | rev = $    10,904 | theta = 0.0100 | sigma=4.13 | mu=7.73
# Week 98 | rev = $    10,891 | theta = 0.0111 | sigma=4.16 | mu=13.89
# Week 99 | rev = $    10,592 | theta = 0.0145 | sigma=4.02 | mu=4.44
# Week100 | rev = $     8,958 | theta = 0.0172 | sigma=3.98 | mu=1.18
# Week101 | rev = $     9,278 | theta = 0.0100 | sigma=7.60 | mu=3.16
# Week102 | rev = $     6,840 | theta = 0.0171 | sigma=3.98 | mu=8.17
# Week103 | rev = $    10,908 | theta = 0.0146 | sigma=4.13 | mu=2.88
# Week104 | rev = $     7,053 | theta = 0.0139 | sigma=4.34 | mu=8.03
# Week105 | rev = $     7,604 | theta = 0.0143 | sigma=4.52 | mu=4.52
# Week106 | rev = $     2,318 | theta = 0.0130 | sigma=4.68 | mu=-1.47
# Week107 | rev = $    19,788 | theta = 0.0182 | sigma=6.09 | mu=28.70
# Week108 | rev = $    10,117 | theta = 0.0300 | sigma=7.87 | mu=28.90
# Week109 | rev = $     5,384 | theta = 0.0328 | sigma=9.02 | mu=31.68
# Week110 | rev = $    10,691 | theta = 0.0248 | sigma=10.52 | mu=40.38
# Week111 | rev = $     9,865 | theta = 0.0235 | sigma=10.93 | mu=15.27
# Week112 | rev = $     3,484 | theta = 0.0236 | sigma=11.39 | mu=-4.02
# Week113 | rev = $    13,428 | theta = 0.0195 | sigma=11.60 | mu=-16.88
# Week114 | rev = $     9,119 | theta = 0.0206 | sigma=12.15 | mu=-2.51
# Week115 | rev = $     4,654 | theta = 0.0227 | sigma=12.22 | mu=14.12
# Week116 | rev = $     5,457 | theta = 0.0242 | sigma=12.28 | mu=14.61
# Week117 | rev = $     7,797 | theta = 0.0251 | sigma=12.23 | mu=3.62
# Week118 | rev = $     4,614 | theta = 0.0288 | sigma=12.32 | mu=13.27
# Week119 | rev = $     6,547 | theta = 0.0312 | sigma=12.39 | mu=11.61
# Week120 | rev = $     9,068 | theta = 0.0260 | sigma=11.89 | mu=14.74
# Week121 | rev = $     4,655 | theta = 0.0163 | sigma=10.86 | mu=11.45
# Week122 | rev = $     7,408 | theta = 0.0114 | sigma=10.03 | mu=6.60
# Week123 | rev = $    10,629 | theta = 0.0100 | sigma=8.32 | mu=10.37
# Week124 | rev = $    14,586 | theta = 0.0100 | sigma=7.89 | mu=17.19
# Week125 | rev = $    25,826 | theta = 0.0100 | sigma=7.43 | mu=11.67
# Week126 | rev = $    18,438 | theta = 0.0123 | sigma=7.55 | mu=13.73
# Week127 | rev = $     8,253 | theta = 0.0160 | sigma=6.57 | mu=4.72
# Week128 | rev = $    14,388 | theta = 0.0112 | sigma=6.38 | mu=17.89
# Week129 | rev = $    17,039 | theta = 0.0100 | sigma=6.37 | mu=17.84
# Week130 | rev = $    17,236 | theta = 0.0100 | sigma=6.54 | mu=11.56
# Week131 | rev = $    24,934 | theta = 0.0100 | sigma=6.93 | mu=1.68
# Week132 | rev = $    22,364 | theta = 0.0151 | sigma=6.17 | mu=8.68
# Week133 | rev = $    26,055 | theta = 0.0181 | sigma=6.54 | mu=6.13
# Week134 | rev = $    46,544 | theta = 0.0228 | sigma=7.04 | mu=11.05
# Week135 | rev = $    33,555 | theta = 0.0299 | sigma=8.06 | mu=29.66
# Week136 | rev = $    47,452 | theta = 0.0381 | sigma=8.25 | mu=13.30
# Week137 | rev = $    20,210 | theta = 0.0462 | sigma=9.01 | mu=26.67
# Week138 | rev = $    26,967 | theta = 0.0488 | sigma=9.13 | mu=7.20
# Week139 | rev = $    40,645 | theta = 0.0467 | sigma=8.98 | mu=7.51
# Week140 | rev = $    21,064 | theta = 0.0329 | sigma=9.56 | mu=10.81
# Week141 | rev = $    21,008 | theta = 0.0348 | sigma=9.80 | mu=16.12
# Week142 | rev = $    22,426 | theta = 0.0306 | sigma=9.94 | mu=12.87
# Week143 | rev = $    11,497 | theta = 0.0275 | sigma=9.91 | mu=8.92
# Week144 | rev = $     9,171 | theta = 0.0274 | sigma=9.74 | mu=-7.45
# Week145 | rev = $    12,168 | theta = 0.0136 | sigma=9.70 | mu=-8.44
# Week146 | rev = $    12,444 | theta = 0.0133 | sigma=9.39 | mu=-0.27
# Week147 | rev = $     9,099 | theta = 0.0127 | sigma=8.93 | mu=-2.57
# Week148 | rev = $    10,888 | theta = 0.0124 | sigma=7.89 | mu=-8.09
# Week149 | rev = $     9,708 | theta = 0.0100 | sigma=7.89 | mu=-5.81
# Week150 | rev = $    15,168 | theta = 0.0100 | sigma=7.03 | mu=-1.86
# Week151 | rev = $    18,192 | theta = 0.0100 | sigma=6.90 | mu=4.65
# Week152 | rev = $     8,402 | theta = 0.0100 | sigma=7.14 | mu=24.68
# Week153 | rev = $    13,936 | theta = 0.0100 | sigma=6.44 | mu=11.82
# Week154 | rev = $    13,842 | theta = 0.0100 | sigma=6.67 | mu=-1.00
# Week155 | rev = $    24,596 | theta = 0.0100 | sigma=6.52 | mu=-0.93
# Week156 | rev = $    15,930 | theta = 0.0128 | sigma=7.22 | mu=25.28
# Week157 | rev = $     2,024 | theta = 0.0170 | sigma=9.30 | mu=45.39
# Week158 | rev = $     9,652 | theta = 0.0170 | sigma=9.06 | mu=-32.29
# Week159 | rev = $     7,324 | theta = 0.0147 | sigma=9.15 | mu=-48.07
# Week160 | rev = $     6,588 | theta = 0.0148 | sigma=9.26 | mu=-34.46
# Week161 | rev = $     9,168 | theta = 0.0148 | sigma=9.32 | mu=-28.43
# Week162 | rev = $    19,918 | theta = 0.0112 | sigma=9.14 | mu=-15.82
# Week163 | rev = $     5,760 | theta = 0.0134 | sigma=10.26 | mu=21.67
# Week164 | rev = $     5,908 | theta = 0.0123 | sigma=10.15 | mu=-16.85
# Week165 | rev = $     8,894 | theta = 0.0129 | sigma=9.82 | mu=-11.99
# Week166 | rev = $     5,752 | theta = 0.0117 | sigma=9.96 | mu=2.13
# Week167 | rev = $     6,718 | theta = 0.0131 | sigma=9.79 | mu=-13.78
# Week168 | rev = $     5,448 | theta = 0.0132 | sigma=9.72 | mu=-9.99
# Week169 | rev = $     6,472 | theta = 0.0122 | sigma=9.14 | mu=-10.89
# Week170 | rev = $     5,567 | theta = 0.0157 | sigma=7.44 | mu=-10.81
# Week171 | rev = $     6,527 | theta = 0.0100 | sigma=7.62 | mu=-13.87
# Week172 | rev = $    10,668 | theta = 0.0100 | sigma=7.58 | mu=-12.86
# Week173 | rev = $     5,207 | theta = 0.0100 | sigma=7.45 | mu=-8.37
# Week174 | rev = $     2,876 | theta = 0.0100 | sigma=7.52 | mu=-5.38
# Week175 | rev = $     4,256 | theta = 0.0100 | sigma=10.16 | mu=-10.00
# Week176 | rev = $     9,772 | theta = 0.0100 | sigma=6.95 | mu=-19.91
# Week177 | rev = $     5,848 | theta = 0.0100 | sigma=6.27 | mu=-15.30
# Week178 | rev = $     5,818 | theta = 0.0100 | sigma=5.95 | mu=-9.43
# Week179 | rev = $     7,916 | theta = 0.0100 | sigma=6.77 | mu=-4.75
# Week180 | rev = $     6,232 | theta = 0.0100 | sigma=5.27 | mu=-21.10
# Week181 | rev = $     6,658 | theta = 0.0100 | sigma=5.22 | mu=-20.05
# Week182 | rev = $     8,108 | theta = 0.0100 | sigma=5.23 | mu=-13.19
# Week183 | rev = $     8,337 | theta = 0.0100 | sigma=5.45 | mu=-4.89
# Week184 | rev = $    16,643 | theta = 0.0100 | sigma=4.20 | mu=-15.46
# Week185 | rev = $    16,701 | theta = 0.0100 | sigma=4.44 | mu=-19.14
# Week186 | rev = $    11,608 | theta = 0.0100 | sigma=4.80 | mu=-17.41
# Week187 | rev = $    29,238 | theta = 0.0107 | sigma=4.62 | mu=-10.58
# Week188 | rev = $     6,243 | theta = 0.0248 | sigma=5.28 | mu=-0.78
# Week189 | rev = $     8,786 | theta = 0.0287 | sigma=5.29 | mu=-19.88
# Week190 | rev = $     9,670 | theta = 0.0240 | sigma=5.35 | mu=-21.96
# Week191 | rev = $     5,856 | theta = 0.0224 | sigma=5.49 | mu=-17.97
# Week192 | rev = $    10,890 | theta = 0.0202 | sigma=5.55 | mu=-11.71
# Week193 | rev = $    16,402 | theta = 0.0122 | sigma=5.80 | mu=-16.44
# Week194 | rev = $     5,482 | theta = 0.0120 | sigma=6.07 | mu=-7.98
# Week195 | rev = $     6,573 | theta = 0.0101 | sigma=6.10 | mu=-12.12
# Week196 | rev = $     7,305 | theta = 0.0100 | sigma=6.03 | mu=-8.72
# Week197 | rev = $     9,532 | theta = 0.0100 | sigma=6.72 | mu=-7.00
# Week198 | rev = $     9,823 | theta = 0.0100 | sigma=6.46 | mu=-6.79
# Week199 | rev = $    10,881 | theta = 0.0100 | sigma=6.14 | mu=-3.68
# Week200 | rev = $     9,750 | theta = 0.0100 | sigma=6.00 | mu=0.65
# Week201 | rev = $     7,384 | theta = 0.0100 | sigma=6.58 | mu=3.97
# Week202 | rev = $     7,512 | theta = 0.0100 | sigma=5.92 | mu=-20.70
# Week203 | rev = $     7,684 | theta = 0.0100 | sigma=5.70 | mu=-19.34
# Week204 | rev = $     9,530 | theta = 0.0100 | sigma=5.69 | mu=-13.69
# Week205 | rev = $     6,676 | theta = 0.0100 | sigma=5.62 | mu=-7.47
# Week206 | rev = $     9,326 | theta = 0.0100 | sigma=5.45 | mu=-22.39
# Week207 | rev = $     6,999 | theta = 0.0100 | sigma=5.98 | mu=-26.44
# Week208 | rev = $     5,211 | theta = 0.0100 | sigma=6.26 | mu=-22.94
# Week209 | rev = $     6,237 | theta = 0.0100 | sigma=5.55 | mu=-7.39
# Week210 | rev = $     8,907 | theta = 0.0161 | sigma=4.32 | mu=-5.05
# Week211 | rev = $    10,936 | theta = 0.0172 | sigma=4.48 | mu=0.18
# Week212 | rev = $    11,290 | theta = 0.0189 | sigma=5.78 | mu=21.33
# Week213 | rev = $     4,874 | theta = 0.0233 | sigma=7.07 | mu=29.49
# Week214 | rev = $     3,701 | theta = 0.0223 | sigma=6.96 | mu=-17.39
# Week215 | rev = $     3,340 | theta = 0.0191 | sigma=6.80 | mu=-4.47
# Week216 | rev = $     5,282 | theta = 0.0187 | sigma=6.74 | mu=-7.82
# Week217 | rev = $     2,972 | theta = 0.0193 | sigma=6.76 | mu=-6.83
# Week218 | rev = $     4,995 | theta = 0.0216 | sigma=6.85 | mu=-7.60
# Week219 | rev = $     4,327 | theta = 0.0159 | sigma=6.64 | mu=-2.41
# Week220 | rev = $     3,810 | theta = 0.0150 | sigma=6.45 | mu=1.05
# Week221 | rev = $     2,798 | theta = 0.0142 | sigma=6.44 | mu=0.52
# Week222 | rev = $     2,593 | theta = 0.0143 | sigma=6.48 | mu=4.19
# Week223 | rev = $     2,729 | theta = 0.0153 | sigma=6.46 | mu=-0.16
# Week224 | rev = $     5,097 | theta = 0.0144 | sigma=6.36 | mu=-1.50
# Week225 | rev = $     3,263 | theta = 0.0190 | sigma=5.37 | mu=-2.10
# Week226 | rev = $     3,875 | theta = 0.0100 | sigma=3.60 | mu=-2.45
# Week227 | rev = $     5,072 | theta = 0.0100 | sigma=7.56 | mu=-2.87
# Week228 | rev = $     4,573 | theta = 0.0100 | sigma=3.41 | mu=0.61
# Week229 | rev = $     5,403 | theta = 0.0100 | sigma=3.43 | mu=2.01
# Week230 | rev = $    11,351 | theta = 0.0100 | sigma=3.35 | mu=2.20
# Week231 | rev = $     7,054 | theta = 0.0100 | sigma=3.41 | mu=4.14
# Week232 | rev = $     6,856 | theta = 0.0117 | sigma=2.95 | mu=-0.78
# Week233 | rev = $    13,976 | theta = 0.0103 | sigma=2.96 | mu=-1.70
# Week234 | rev = $    25,400 | theta = 0.0100 | sigma=3.09 | mu=1.72
# Week235 | rev = $     9,328 | theta = 0.0100 | sigma=3.74 | mu=10.47
# Week236 | rev = $    17,899 | theta = 0.0261 | sigma=3.40 | mu=-2.71
# Week237 | rev = $    37,011 | theta = 0.0260 | sigma=3.66 | mu=-1.04
# Week238 | rev = $    17,464 | theta = 0.0396 | sigma=4.97 | mu=7.11
# Week239 | rev = $    11,928 | theta = 0.0458 | sigma=5.25 | mu=-3.34
# Week240 | rev = $    22,859 | theta = 0.0100 | sigma=11.62 | mu=-4.76
# Week241 | rev = $     6,780 | theta = 0.0540 | sigma=5.74 | mu=8.78
# Week242 | rev = $     8,184 | theta = 0.0550 | sigma=5.78 | mu=-1.34
# Week243 | rev = $    11,166 | theta = 0.0561 | sigma=5.83 | mu=0.27
# Week244 | rev = $     9,512 | theta = 0.0544 | sigma=5.85 | mu=-1.13
# Week245 | rev = $     7,720 | theta = 0.0330 | sigma=6.01 | mu=0.46
# Week246 | rev = $    10,258 | theta = 0.0419 | sigma=6.02 | mu=1.84
# Week247 | rev = $     7,172 | theta = 0.0427 | sigma=5.92 | mu=3.97
# Week248 | rev = $     7,490 | theta = 0.0317 | sigma=5.43 | mu=2.86
# Week249 | rev = $     9,450 | theta = 0.0124 | sigma=5.83 | mu=2.40
# Week250 | rev = $     9,917 | theta = 0.0137 | sigma=5.45 | mu=-1.33
# Week251 | rev = $     9,921 | theta = 0.0121 | sigma=4.28 | mu=-1.12
# Week252 | rev = $    10,123 | theta = 0.0104 | sigma=3.82 | mu=-1.14
# Week253 | rev = $     9,761 | theta = 0.0110 | sigma=3.70 | mu=-2.49
# Week254 | rev = $    11,734 | theta = 0.0100 | sigma=3.85 | mu=0.26
# Week255 | rev = $     7,895 | theta = 0.0100 | sigma=3.74 | mu=1.48
# Week256 | rev = $     8,260 | theta = 0.0100 | sigma=3.86 | mu=3.18
# Week257 | rev = $    16,939 | theta = 0.0100 | sigma=3.86 | mu=6.20
# Week258 | rev = $    10,676 | theta = 0.0105 | sigma=4.38 | mu=16.25
# Week259 | rev = $    10,645 | theta = 0.0134 | sigma=4.87 | mu=9.75
# Week260 | rev = $    15,119 | theta = 0.0174 | sigma=5.12 | mu=2.77
# Week261 | rev = $     5,290 | theta = 0.0234 | sigma=5.69 | mu=18.23
# Week262 | rev = $    13,835 | theta = 0.0296 | sigma=5.70 | mu=-6.56
# Week263 | rev = $     5,714 | theta = 0.0223 | sigma=6.34 | mu=3.89
# Week264 | rev = $    11,055 | theta = 0.0219 | sigma=7.36 | mu=13.93
# Week265 | rev = $     9,964 | theta = 0.0134 | sigma=9.28 | mu=50.99
# Week266 | rev = $     9,444 | theta = 0.0169 | sigma=10.76 | mu=32.63
# Week267 | rev = $    12,078 | theta = 0.0190 | sigma=11.31 | mu=8.19
# Week268 | rev = $    13,004 | theta = 0.0212 | sigma=11.85 | mu=24.03
# Week269 | rev = $     7,882 | theta = 0.0229 | sigma=12.31 | mu=22.44
# Week270 | rev = $    14,754 | theta = 0.0243 | sigma=12.75 | mu=13.23
# Week271 | rev = $     7,596 | theta = 0.0292 | sigma=12.94 | mu=3.07
# Week272 | rev = $    10,521 | theta = 0.0299 | sigma=12.78 | mu=6.92
# Week273 | rev = $     8,067 | theta = 0.0313 | sigma=12.74 | mu=1.81
# Week274 | rev = $     8,387 | theta = 0.0323 | sigma=12.55 | mu=0.20
# Week275 | rev = $     8,513 | theta = 0.0348 | sigma=12.50 | mu=-0.14
# Week276 | rev = $     9,832 | theta = 0.0354 | sigma=12.19 | mu=10.67
# Week277 | rev = $     7,959 | theta = 0.0375 | sigma=11.65 | mu=10.64
# Week278 | rev = $     7,715 | theta = 0.0489 | sigma=10.22 | mu=0.14
# Week279 | rev = $     9,205 | theta = 0.0366 | sigma=8.51 | mu=-4.99
# Week280 | rev = $     7,717 | theta = 0.0293 | sigma=7.93 | mu=3.62
# Week281 | rev = $    10,579 | theta = 0.0318 | sigma=7.07 | mu=1.99
# Week282 | rev = $     8,994 | theta = 0.0337 | sigma=6.24 | mu=0.06
# Week283 | rev = $     8,815 | theta = 0.0291 | sigma=5.37 | mu=-3.73
# Week284 | rev = $     9,937 | theta = 0.0378 | sigma=4.64 | mu=-3.64
# Week285 | rev = $    10,271 | theta = 0.0411 | sigma=4.28 | mu=0.51
# Week286 | rev = $    36,756 | theta = 0.0332 | sigma=4.11 | mu=-1.17
# Week287 | rev = $    28,677 | theta = 0.0308 | sigma=6.07 | mu=20.29
# Week288 | rev = $    27,154 | theta = 0.0371 | sigma=6.72 | mu=10.11
# Week289 | rev = $    26,440 | theta = 0.0368 | sigma=6.90 | mu=4.97
# Week290 | rev = $    33,755 | theta = 0.0314 | sigma=7.03 | mu=7.23
# Week291 | rev = $    73,122 | theta = 0.0336 | sigma=8.02 | mu=9.52
# Week292 | rev = $    33,428 | theta = 0.0441 | sigma=10.63 | mu=12.84
# Week293 | rev = $    33,794 | theta = 0.0429 | sigma=11.45 | mu=8.65
# Week294 | rev = $    22,080 | theta = 0.0447 | sigma=11.82 | mu=10.99
# Week295 | rev = $    12,152 | theta = 0.0463 | sigma=11.97 | mu=4.86
# Week296 | rev = $     8,848 | theta = 0.0493 | sigma=12.01 | mu=-7.91
# Week297 | rev = $     9,170 | theta = 0.0485 | sigma=12.04 | mu=-8.22
# Week298 | rev = $    10,866 | theta = 0.0488 | sigma=12.04 | mu=2.31
# Week299 | rev = $    13,431 | theta = 0.0487 | sigma=12.02 | mu=2.39
# Week300 | rev = $    12,213 | theta = 0.0665 | sigma=11.28 | mu=3.89
# Week301 | rev = $    21,769 | theta = 0.0540 | sigma=10.58 | mu=6.06
# Week302 | rev = $    13,878 | theta = 0.0562 | sigma=10.53 | mu=2.19
# Week303 | rev = $    14,789 | theta = 0.0591 | sigma=10.44 | mu=1.89
# Week304 | rev = $    26,231 | theta = 0.0623 | sigma=9.73 | mu=1.13
# Week305 | rev = $    19,979 | theta = 0.0979 | sigma=7.64 | mu=5.24
# Week306 | rev = $    20,791 | theta = 0.0688 | sigma=5.83 | mu=7.17
# Week307 | rev = $    15,903 | theta = 0.0638 | sigma=5.38 | mu=8.96
# Week308 | rev = $    17,120 | theta = 0.0444 | sigma=5.25 | mu=7.58
# Week309 | rev = $    15,259 | theta = 0.0501 | sigma=5.42 | mu=7.44
# Week310 | rev = $     9,506 | theta = 0.0763 | sigma=5.75 | mu=2.51
# Week311 | rev = $    18,266 | theta = 0.0481 | sigma=6.64 | mu=19.28
# Week312 | rev = $     3,346 | theta = 0.0459 | sigma=7.32 | mu=20.03
# Week313 | rev = $     9,637 | theta = 0.0393 | sigma=7.50 | mu=-18.34
# Week314 | rev = $    10,741 | theta = 0.0301 | sigma=7.75 | mu=-15.86
# Week315 | rev = $    -3,701 | theta = 0.0445 | sigma=7.98 | mu=-8.70
# Week316 | rev = $    19,634 | theta = 0.0193 | sigma=7.96 | mu=-36.46
# Week317 | rev = $     6,190 | theta = 0.0179 | sigma=8.09 | mu=-20.78
# Week318 | rev = $         0 | theta = 0.0100 | sigma=12.54 | mu=79.79
# Week319 | rev = $    26,822 | theta = 0.0221 | sigma=25.67 | mu=110.00
# Week320 | rev = $     4,457 | theta = 0.0225 | sigma=26.42 | mu=34.54
# Week321 | rev = $     9,870 | theta = 0.0221 | sigma=26.45 | mu=-37.34
# Week322 | rev = $     9,535 | theta = 0.0202 | sigma=26.38 | mu=-38.73
# Week323 | rev = $    11,348 | theta = 0.0211 | sigma=26.52 | mu=-13.65
# Week324 | rev = $    13,231 | theta = 0.0215 | sigma=26.38 | mu=-0.46
# Week325 | rev = $    15,186 | theta = 0.0213 | sigma=26.23 | mu=0.60
# Week326 | rev = $    10,266 | theta = 0.0217 | sigma=26.23 | mu=2.02
# Week327 | rev = $     9,314 | theta = 0.0208 | sigma=26.22 | mu=-4.82
# Week328 | rev = $     9,880 | theta = 0.0214 | sigma=26.07 | mu=-2.86
# Week329 | rev = $    19,302 | theta = 0.0215 | sigma=26.13 | mu=0.14
# Week330 | rev = $    10,531 | theta = 0.0219 | sigma=26.17 | mu=5.77
# Week331 | rev = $    10,142 | theta = 0.0354 | sigma=24.35 | mu=-1.17
# Week332 | rev = $     9,311 | theta = 0.0119 | sigma=9.75 | mu=0.51
# Week333 | rev = $    20,150 | theta = 0.0100 | sigma=7.56 | mu=3.08
# Mean weekly revenue: $10,229
# Std weekly revenue:  $8,232
# Sharpe (weekly):     1.24
# Worst week:          $-3,701
# % positive weeks:    99%
# Unique revenues: 332

# %%
#trimmed mean sharpe

ciso_sorted_rev = sorted(ciso_revenues)
ciso_trimmed = ciso_sorted_rev[5:-5]
print(f"CISO Trimmed mean: ${np.mean(ciso_trimmed):,.0f}")
print(f"CISO Trimmed Sharpe: {np.mean(ciso_trimmed) / np.std(ciso_trimmed):.2f}")


nyiso_sorted_rev = sorted(nyiso_revenues)
nyiso_trimmed = nyiso_sorted_rev[5:-5]
print(f"NYISO Trimmed mean: ${np.mean(nyiso_trimmed):,.0f}")
print(f"NYISO Trimmed Sharpe: {np.mean(nyiso_trimmed) / np.std(nyiso_trimmed):.2f}")
# Out:
# CISO Trimmed mean: $13,105
# CISO Trimmed Sharpe: 1.75
# NYISO Trimmed mean: $9,798
# NYISO Trimmed Sharpe: 1.51

# %%
#weekly revenue bar chart
fig, axes = plt.subplots(2, 1, figsize=(14, 12))

axes[0].bar(range(len(ciso_revenues)), ciso_revenues, 
            color=['green' if r > 0 else 'red' for r in ciso_revenues], alpha=0.7)
axes[0].axhline(y=0, color='black', linewidth=0.5)
axes[0].axhline(y=np.mean(ciso_revenues), color='blue', linestyle='--', 
                label=f'Mean: ${np.mean(ciso_revenues):,.0f}')
axes[0].set_ylabel("Revenue ($)")
axes[0].set_title("CISO Weekly Revenue")
axes[0].legend()

axes[1].bar(range(len(nyiso_revenues)), nyiso_revenues, 
            color=['green' if r > 0 else 'red' for r in nyiso_revenues], alpha=0.7)
axes[1].axhline(y=0, color='black', linewidth=0.5)
axes[1].axhline(y=np.mean(nyiso_revenues), color='blue', linestyle='--', 
                label=f'Mean: ${np.mean(nyiso_revenues):,.0f}')
axes[1].set_ylabel("Revenue ($)")
axes[1].set_title("NYISO Weekly Revenue")
axes[1].legend()

plt.show()

# %%
#volalitity vs revenue scatter with correlation.
eval_window = 24 * 7

fig, axes = plt.subplots(2,1,figsize=(14,12))

ciso_vols = []
for r in ciso_results:
    start = r["eval_start"]
    week_prices = ciso["price_usd_mwh"].values[start:start + eval_window]
    r["volatility"] = np.std(week_prices)
    ciso_vols.append(r["volatility"])

axes[0].scatter(ciso_vols, ciso_revenues, alpha=0.5)
z = np.polyfit(ciso_vols, ciso_revenues, 1)
x_line = np.linspace(min(ciso_vols), max(ciso_vols), 100)
axes[0].plot(x_line, np.polyval(z, x_line), 'r--', 
             label=f'Correlation: {np.corrcoef(ciso_vols, ciso_revenues)[0,1]:.2f}')
axes[0].axhline(y=0, color='black', linewidth=0.5)
axes[0].set_xlabel("Weekly price std dev ($/MWh)")
axes[0].set_ylabel("Revenue ($)")
axes[0].set_title("CISO Volatility vs Revenue")
axes[0].legend()


nyiso_vols = []
for r in nyiso_results:
    start = r["eval_start"]
    week_prices = nyiso["price_usd_mwh"].values[start:start + eval_window]
    r["volatility"] = np.std(week_prices)
    nyiso_vols.append(r["volatility"])

axes[1].scatter(nyiso_vols, nyiso_revenues, alpha=0.5)
z = np.polyfit(nyiso_vols, nyiso_revenues, 1)
x_line = np.linspace(min(nyiso_vols), max(nyiso_vols), 100)
axes[1].plot(x_line, np.polyval(z, x_line), 'r--', 
             label=f'Correlation: {np.corrcoef(nyiso_vols, nyiso_revenues)[0,1]:.2f}')
axes[1].axhline(y=0, color='black', linewidth=0.5)
axes[1].set_xlabel("Weekly price std dev ($/MWh)")
axes[1].set_ylabel("Revenue ($)")
axes[1].set_title("NYISO Volatility vs Revenue")
axes[1].legend()



plt.show()

print(f"CISO Correlation (vol, rev): {np.corrcoef(ciso_vols, ciso_revenues)[0,1]:.2f}")
print(f"NYISO Correlation (vol, rev): {np.corrcoef(nyiso_vols, nyiso_revenues)[0,1]:.2f}")
# Out:
# CISO Correlation (vol, rev): 0.89
# NYISO Correlation (vol, rev): 0.38

# %%
#cumulative p/l and max dd
fig, axes = plt.subplots(2,1,figsize=(14,12))

ciso_cumulative = np.cumsum(ciso_revenues)
axes[0].plot(ciso_cumulative, color='blue')
axes[0].fill_between(range(len(ciso_cumulative)), ciso_cumulative, 
                     where=ciso_cumulative >= 0, color='green', alpha=0.2)
axes[0].fill_between(range(len(ciso_cumulative)), ciso_cumulative, 
                     where=ciso_cumulative < 0, color='red', alpha=0.2)
axes[0].axhline(y=0, color='black', linewidth=0.5)
axes[0].set_xlabel("Week")
axes[0].set_ylabel("Cumulative Revenue ($)")
axes[0].set_title("Cumulative P&L -- CISO")

nyiso_cumulative = np.cumsum(nyiso_revenues)
axes[1].plot(nyiso_cumulative, color='blue')
axes[1].fill_between(range(len(nyiso_cumulative)), nyiso_cumulative, 
                     where=nyiso_cumulative >= 0, color='green', alpha=0.2)
axes[1].fill_between(range(len(nyiso_cumulative)), nyiso_cumulative, 
                     where=nyiso_cumulative < 0, color='red', alpha=0.2)
axes[1].axhline(y=0, color='black', linewidth=0.5)
axes[1].set_xlabel("Week")
axes[1].set_ylabel("Cumulative Revenue ($)")
axes[1].set_title("Cumulative P&L -- NYISO")

plt.show()

ciso_peak = np.maximum.accumulate(ciso_cumulative)
ciso_drawdown = ciso_cumulative - ciso_peak
print(f"CISO Max drawdown: ${ciso_drawdown.min():,.0f}")

nyiso_peak = np.maximum.accumulate(nyiso_cumulative)
nyiso_drawdown = nyiso_cumulative - nyiso_peak
print(f"NYISO Max drawdown: ${nyiso_drawdown.min():,.0f}")
# Out:
# CISO Max drawdown: $-3,582
# NYISO Max drawdown: $-7,038

# %%
#theta, sigma vs time - ciso
ciso_thetas = [r["theta"] for r in ciso_results]
ciso_sigmas = [r["sigma"] for r in ciso_results]

fig, axes = plt.subplots(2, 1, figsize=(14, 8))
axes[0].plot(ciso_thetas)
axes[0].set_ylabel("CISO theta")
axes[1].plot(ciso_sigmas)
axes[1].set_ylabel("CISO sigma")
plt.xlabel("Week - CISO")
plt.tight_layout()
plt.show()

# %%
#theta, sigma vs time - nyiso
nyiso_thetas = [r["theta"] for r in nyiso_results]
nyiso_sigmas = [r["sigma"] for r in nyiso_results]

fig, axes = plt.subplots(2, 1, figsize=(14, 8))
axes[0].plot(nyiso_thetas)
axes[0].set_ylabel("NYISO theta")
axes[1].plot(nyiso_sigmas)
axes[1].set_ylabel("NYISO sigma")
plt.xlabel("Week")
plt.tight_layout()
plt.show()

# %%
#variance decomposition CISO
eval_window = 24 * 7

diagnostics = []

for r in ciso_results:
    start = r["eval_start"]
    week_prices = ciso["price_usd_mwh"].values[start:start + eval_window]
    
    total_vol = np.std(week_prices)
    
    daily_spreads = []
    for d in range(7):
        day_prices = week_prices[d * 24:(d + 1) * 24]
        daily_spreads.append(day_prices.max() - day_prices.min())
    avg_spread = np.mean(daily_spreads)
    
    r["total_vol"] = total_vol
    r["avg_spread"] = avg_spread

weeks = range(len(ciso_results))
total_vols = [r["total_vol"] for r in ciso_results]
avg_spreads = [r["avg_spread"] for r in ciso_results]
sigmas = [r["sigma"] for r in ciso_results]

fig, axes = plt.subplots(3, 1, figsize=(14, 12))

# 1. Raw price vol vs residual sigma over time
axes[0].plot(weeks, total_vols, label="Total price std dev", alpha=0.7)
axes[0].plot(weeks, sigmas, label="OU residual σ", alpha=0.7)
axes[0].set_ylabel("$/MWh")
axes[0].set_title("Total Volatility vs Residual Volatility")
axes[0].legend()

# 2. Fraction of variance explained by seasonal model
variance_explained = [1 - (s**2 / tv**2) if tv > 0 else 0 
                      for s, tv in zip(sigmas, total_vols)]
axes[1].plot(weeks, variance_explained)
axes[1].set_ylabel("R² (fraction explained)")
axes[1].set_title("Seasonal Model Explanatory Power")
axes[1].axhline(y=np.mean(variance_explained), color='r', 
                linestyle='--', label=f"Mean: {np.mean(variance_explained):.2f}")
axes[1].legend()

# 3. Average daily spread over time
axes[2].plot(weeks, avg_spreads, alpha=0.7)
z = np.polyfit(weeks, avg_spreads, 1)
axes[2].plot(weeks, np.polyval(z, list(weeks)), 'r--', 
             label=f"Trend: {z[0]:+.2f} $/week")
axes[2].set_ylabel("$/MWh")
axes[2].set_xlabel("Week")
axes[2].set_title("Average Daily Price Spread (Max - Min)")
axes[2].legend()

plt.tight_layout()
plt.show()

# %%
#variance decomposition NYISO

eval_window = 24 * 7

diagnostics = []

for r in nyiso_results:
    start = r["eval_start"]
    week_prices = nyiso["price_usd_mwh"].values[start:start + eval_window]
    
    total_vol = np.std(week_prices)
    
    daily_spreads = []
    for d in range(7):
        day_prices = week_prices[d * 24:(d + 1) * 24]
        daily_spreads.append(day_prices.max() - day_prices.min())
    avg_spread = np.mean(daily_spreads)
    
    r["total_vol"] = total_vol
    r["avg_spread"] = avg_spread

weeks = range(len(nyiso_results))
total_vols = [r["total_vol"] for r in nyiso_results]
avg_spreads = [r["avg_spread"] for r in nyiso_results]
sigmas = [r["sigma"] for r in nyiso_results]

fig, axes = plt.subplots(3, 1, figsize=(14, 12))

# 1. Raw price vol vs residual sigma over time
axes[0].plot(weeks, total_vols, label="Total price std dev", alpha=0.7)
axes[0].plot(weeks, sigmas, label="OU residual σ", alpha=0.7)
axes[0].set_ylabel("$/MWh")
axes[0].set_title("Total Volatility vs Residual Volatility")
axes[0].legend()

# 2. Fraction of variance explained by seasonal model
variance_explained = [1 - (s**2 / tv**2) if tv > 0 else 0 
                      for s, tv in zip(sigmas, total_vols)]
axes[1].plot(weeks, variance_explained)
axes[1].set_ylabel("R² (fraction explained)")
axes[1].set_title("Seasonal Model Explanatory Power")
axes[1].axhline(y=np.mean(variance_explained), color='r', 
                linestyle='--', label=f"Mean: {np.mean(variance_explained):.2f}")
axes[1].legend()

# 3. Average daily spread over time
axes[2].plot(weeks, avg_spreads, alpha=0.7)
z = np.polyfit(weeks, avg_spreads, 1)
axes[2].plot(weeks, np.polyval(z, list(weeks)), 'r--', 
             label=f"Trend: {z[0]:+.2f} $/week")
axes[2].set_ylabel("$/MWh")
axes[2].set_xlabel("Week")
axes[2].set_title("Average Daily Price Spread (Max - Min)")
axes[2].legend()

plt.tight_layout()
plt.show()

# %%
#perfect foresight comparison - CISO
eval_window = 24 * 7
train_window = 24 * 365
soc_grid = np.linspace(0, 100, 81)
params = {"u_max": 25, "eta": 0.85, "S_max": 100, "S_0": 0, "dt": 1}


pf_results = []

for r in ciso_results:
    start = r["eval_start"]
    eval_data = ciso.iloc[start:start + eval_window].copy()  
    actual_prices = eval_data["price_usd_mwh"].values

    train_end = start
    train_data = ciso.iloc[train_end - train_window:train_end]
    params["q"] = train_data["price_usd_mwh"].mean()
    
    pf_rev = perfect_foresight(actual_prices, soc_grid, params)
    pf_results.append(pf_rev)

opt_revs = [r["revenue"] for r in ciso_results]

capture = [o / p if p > 0 else 0 for o, p in zip(opt_revs, pf_results)]
mean_of_ratios = np.mean(capture)
ratio_of_means = np.sum(opt_revs) / np.sum(pf_results)

print("CISO:")
print(f"Value capture (mean of ratios): {mean_of_ratios:.1%}")
print(f"Value capture (ratio of means): {ratio_of_means:.1%}")
print(f"Median value capture: {np.median(capture):.1%}")
print(f"Mean optimal: ${np.mean(opt_revs):,.0f}")
print(f"Mean perfect foresight: ${np.mean(pf_results):,.0f}")
# Out:
# CISO:
# Value capture (mean of ratios): 74.5%
# Value capture (ratio of means): 82.0%
# Median value capture: 80.7%
# Mean optimal: $13,717
# Mean perfect foresight: $16,718

# %%
#perfect foresight comparison -- NYISO
eval_window = 24 * 7
train_window = 24 * 365
soc_grid = np.linspace(0, 100, 81)
params = {"u_max": 25, "eta": 0.85, "S_max": 100, "S_0": 0, "dt": 1}


pf_results = []

for r in nyiso_results:
    start = r["eval_start"]
    eval_data = nyiso.iloc[start:start + eval_window].copy() 
    actual_prices = eval_data["price_usd_mwh"].values

    train_end = start
    train_data = nyiso.iloc[train_end - train_window:train_end]
    params["q"] = train_data["price_usd_mwh"].mean()
    
    pf_rev = perfect_foresight(actual_prices, soc_grid, params)
    pf_results.append(pf_rev)

opt_revs = [r["revenue"] for r in nyiso_results]

capture = [o / p if p > 0 else 0 for o, p in zip(opt_revs, pf_results)]
mean_of_ratios = np.mean(capture)
ratio_of_means = np.sum(opt_revs) / np.sum(pf_results)

print("NYISO:")
print(f"Value capture (mean of ratios): {mean_of_ratios:.1%}")
print(f"Value capture (ratio of means): {ratio_of_means:.1%}")
print(f"Median value capture: {np.median(capture):.1%}")
print(f"Mean optimal: ${np.mean(opt_revs):,.0f}")
print(f"Mean perfect foresight: ${np.mean(pf_results):,.0f}")
# Out:
# NYISO:
# Value capture (mean of ratios): 86.4%
# Value capture (ratio of means): 71.8%
# Median value capture: 87.9%
# Mean optimal: $10,229
# Mean perfect foresight: $14,251
